# %%
# %matplotlib inline

import matplotlib
import matplotlib.pyplot as plt
import pyclesperanto_prototype as cle
cle.select_device('RTX')
print("Using OpenCL device " + cle.get_device().name)

from scipy import ndimage as ndi
import napari
import numpy as np
import cv2
import tifffile

from oiffile import OifFile
from confocal_3D.OifImageViewer import OifImageViewer
# Out:
# Using OpenCL device NVIDIA RTX A5000

# %%
path = "/home/dkermany/data/Bone_Project/oibs/FV10__20190620_111343.oib"

with OifFile(path) as oif:
    viewer = OifImageViewer(oif)
# Out:
# Image shape: (3, 76, 2404, 3376)
# Axes: CZYX
# Dtype: uint16
# Intervals: X (1.242um) Y (1.242um) Z (2660nm)

# %%
original_image = cle.push(viewer._arr[2])

plt.figure(figsize=(18,12))
cle.imshow(original_image[40])

# %%
img_gaussian = cle.gaussian_blur(original_image, sigma_x=2, sigma_y=2, sigma_z=2)
plt.figure(figsize=(18,12))
cle.imshow(img_gaussian[40])

# %%
backgrund_subtracted = cle.top_hat_box(img_gaussian, radius_x=10, radius_y=10, radius_z=5)

plt.figure(figsize=(18,12))
cle.imshow(backgrund_subtracted[40])

# %%
# thicker_membranes = cle.maximum_sphere(backgrund_subtracted, radius_x=3, radius_y=3, radius_z=3)

# plt.figure(figsize=(18,12))
# cle.imshow(thicker_membranes[40])

# %%
# thresh1 = cle.threshold_otsu(thicker_membranes)

# plt.figure(figsize=(18,12))
# cle.imshow(thresh1[40])

# %%
thresh2 = cle.threshold_otsu(backgrund_subtracted)

plt.figure(figsize=(18,12))
cle.imshow(thresh2[40])

# %%
# Morphological openning
kernel = np.ones((7,7), np.uint8)
erosion = cle.erode_box(thresh2)
dilation = cle.dilate_box(erosion)

plt.figure(figsize=(18,12))
cle.imshow(dilation[40])

# %%
dilation.shape
# Out:
# (76, 2404, 3376)

# %%
del erosion, backgrund_subtracted, img_gaussian, original_image

# %%
labels = cle.connected_components_labeling_box(dilation)
print(labels.shape)
plt.figure(figsize=(18,12))
cle.imshow(labels[40], labels=True)
# Out:
# (76, 2404, 3376)

# %%
cle.statistics_of_background_and_labelled_pixels(dilation, labels)
# Out:
# {'label': array([    1,     2,     3, ..., 10818, 10819, 10820]),
#  'original_label': array([    0,     1,     2, ..., 10817, 10818, 10819]),
#  'bbox_min_x': array([   0.,    0.,    0., ..., 3369., 3371., 3371.], dtype=float32),
#  'bbox_min_y': array([   0.,  187.,  560., ..., 1140., 1054., 2384.], dtype=float32),
#  'bbox_min_z': array([ 0.,  0., 27., ...,  0., 52.,  9.], dtype=float32),
#  'bbox_max_x': array([3.375e+03, 2.852e+03, 1.000e+00, ..., 3.375e+03, 3.375e+03,
#         3.373e+03], dtype=float32),
#  'bbox_max_y': array([2403.,  645.,  562., ..., 1145., 1068., 2387.], dtype=float32),
#  'bbox_max_z': array([75., 75., 30., ...,  8., 66., 12.], dtype=float32),
#  'bbox_width': array([3.376e+03, 2.853e+03, 2.000e+00, ..., 7.000e+00, 5.000e+00,
#         3.000e+00], dtype=float32),
#  'bbox_height': array([2404.,  459.,    3., ...,    6.,   15.,    4.], dtype=float32),
#  'bbox_depth': array([76., 76.,  4., ...,  9., 15.,  4.], dtype=float32),
#  'min_intensity': array([0., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  'max_intensity': array([0., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  'sum_intensity': array([0.00000e+00, 2.44122e+06, 2.40000e+01, ..., 2.36000e+02,
#         5.77000e+02, 4.50000e+01], dtype=float32),
#  'area': array([5.864065e+08, 2.441220e+06, 2.400000e+01, ..., 2.360000e+02,
#         5.770000e+02, 4.500000e+01], dtype=float32),
#  'mean_intensity': array([0., 1., 1., ..., 1., 1., 1.], dtype=float32),
#  'sum_intensity_times_x': array([0.000000e+00, 4.320791e+09, 1.200000e+01, ..., 7.957960e+05,
#         1.946650e+06, 1.517400e+05], dtype=float32),
#  'mass_center_x': array([          nan, 1.7699310e+03, 5.0000000e-01, ..., 3.3720168e+03,
#         3.3737434e+03, 3.3720000e+03], dtype=float32),
#  'sum_intensity_times_y': array([0.0000000e+00, 1.0127047e+09, 1.3464000e+04, ..., 2.6957000e+05,
#         6.1227700e+05, 1.0734300e+05], dtype=float32),
#  'mass_center_y': array([       nan,  414.83548,  561.     , ..., 1142.2457 , 1061.1387 ,
#         2385.4001 ], dtype=float32),
#  'sum_intensity_times_z': array([0.000000e+00, 8.273679e+07, 6.840000e+02, ..., 7.530000e+02,
#         3.421700e+04, 4.770000e+02], dtype=float32),
#  'mass_center_z': array([      nan, 33.891575, 28.5     , ...,  3.190678, 59.30156 ,
#         10.6     ], dtype=float32),
#  'sum_x': array([9.9584665e+11, 4.3207910e+09, 1.2000000e+01, ..., 7.9579600e+05,
#         1.9466500e+06, 1.5174000e+05], dtype=float32),
#  'centroid_x': array([1.6982189e+03, 1.7699310e+03, 5.0000000e-01, ..., 3.3720168e+03,
#         3.3737434e+03, 3.3720000e+03], dtype=float32),
#  'sum_y': array([7.0191383e+11, 1.0127047e+09, 1.3464000e+04, ..., 2.6957000e+05,
#         6.1227700e+05, 1.0734300e+05], dtype=float32),
#  'centroid_y': array([1196.9747 ,  414.83548,  561.     , ..., 1142.2457 , 1061.1387 ,
#         2385.4001 ], dtype=float32),
#  'sum_z': array([2.2083789e+10, 8.2736792e+07, 6.8400000e+02, ..., 7.5300000e+02,
#         3.4217000e+04, 4.7700000e+02], dtype=float32),
#  'centroid_z': array([37.65952 , 33.891575, 28.5     , ...,  3.190678, 59.30156 ,
#         10.6     ], dtype=float32),
#  'sum_distance_to_centroid': array([6.5811376e+11, 1.4806993e+09, 3.3917568e+01, ..., 7.1832959e+02,
#         2.7534182e+03, 7.5437531e+01], dtype=float32),
#  'mean_distance_to_centroid': array([1122.2825   ,  606.54065  ,    1.4132321, ...,    3.0437694,
#            4.7719555,    1.6763896], dtype=float32),
#  'sum_distance_to_mass_center': array([          nan, 1.4806993e+09, 3.3917568e+01, ..., 7.1832959e+02,
#         2.7534182e+03, 7.5437531e+01], dtype=float32),
#  'mean_distance_to_mass_center': array([        nan, 606.54065  ,   1.4132321, ...,   3.0437694,
#           4.7719555,   1.6763896], dtype=float32),
#  'standard_deviation_intensity': array([0., 0., 0., ..., 0., 0., 0.], dtype=float32),
#  'max_distance_to_centroid': array([2.0832336e+03, 1.7741271e+03, 1.8708286e+00, ..., 5.3492351e+00,
#         8.5354595e+00, 2.3495555e+00], dtype=float32),
#  'max_distance_to_mass_center': array([         nan, 1774.1271   ,    1.8708286, ...,    5.349235 ,
#            8.5354595,    2.3495555], dtype=float32),
#  'mean_max_distance_to_centroid_ratio': array([1.8562472, 2.9249928, 1.3237944, ..., 1.7574377, 1.7886713,
#         1.401557 ], dtype=float32),
#  'mean_max_distance_to_mass_center_ratio': array([      nan, 2.9249928, 1.3237944, ..., 1.7574377, 1.7886713,
#         1.401557 ], dtype=float32)}

# %%
labels = cle.erode_labels(labels, relabel_islands=True)
labels = cle.erode_labels(labels, relabel_islands=True)
plt.figure(figsize=(18,12))
cle.imshow(labels[40], labels=True)

# %%
dil3d = cle.dilate_labels(labels)
plt.figure(figsize=(18,12))
cle.imshow(dil3d[40], labels=True)

# %%
del dilation, labels
smalls_filtered_out = cle.exclude_labels_outside_size_range(dil3d, None, 240, 6580)
plt.figure(figsize=(18,12))
cle.imshow(smalls_filtered_out[40], labels=True)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Input In [32], in <cell line: 2>()
#       1 del dilation, labels
# ----> 2 smalls_filtered_out = cle.exclude_labels_outside_size_range(dil3d, None, 240, 6580)
#       3 plt.figure(figsize=(8,5))
#       4 cle.imshow(smalls_filtered_out[40], labels=True)
#
# File ~/.local/share/virtualenvs/BoneSegmentation-C6QGg7XR/lib/python3.9/site-packages/pyclesperanto_prototype/_tier0/_plugin_function.py:71, in plugin_function.<locals>.worker_function(*args, **kwargs)
#      68         bound.arguments[key] = output_creator(*bound.args[:len(sig2.parameters)])
#      70 # call the decorated function
# ---> 71 return function(*bound.args, **bound.kwargs)
#
# File ~/.local/share/virtualenvs/BoneSegmentation-C6QGg7XR/lib/python3.9/site-packages/pyclesperanto_prototype/_tier3/_exclude_labels_outside_size_range.py:31, in exclude_labels_outside_size_range(source, destination, minimum_size, maximum_size)
#      28 from .._tier9 import statistics_of_background_and_labelled_pixels
#      29 from .._tier9 import push_regionprops_column
# ---> 31 regionprops = statistics_of_background_and_labelled_pixels(None, source)
#      33 values_vector = push_regionprops_column(regionprops, 'area')
#      36 above = create_like(values_vector)
#
# File ~/.local/share/virtualenvs/BoneSegmentation-C6QGg7XR/lib/python3.9/site-packages/pyclesperanto_prototype/_tier0/_plugin_function.py:71, in plugin_function.<locals>.worker_function(*args, **kwargs)
#      68         bound.arguments[key] = output_creator(*bound.args[:len(sig2.parameters)])
#      70 # call the decorated function
# ---> 71 return function(*bound.args, **bound.kwargs)
#
# File ~/.local/share/virtualenvs/BoneSegmentation-C6QGg7XR/lib/python3.9/site-packages/pyclesperanto_prototype/_tier9/_statistics_of_background_and_labelled_pixels.py:36, in statistics_of_background_and_labelled_pixels(source, labelmap)
#      33 from .._tier9 import statistics_of_labelled_pixels
#      35 temp = add_image_and_scalar(labelmap, scalar=1)
# ---> 36 regionprops = statistics_of_labelled_pixels(source, temp)
#      38 if isinstance(regionprops, dict):
#      39     # correct regionprops label
#      40     regionprops['original_label'] = regionprops['label'] - 1
#
# File ~/.local/share/virtualenvs/BoneSegmentation-C6QGg7XR/lib/python3.9/site-packages/pyclesperanto_prototype/_tier0/_plugin_function.py:71, in plugin_function.<locals>.worker_function(*args, **kwargs)
#      68         bound.arguments[key] = output_creator(*bound.args[:len(sig2.parameters)])
#      70 # call the decorated function
# ---> 71 return function(*bound.args, **bound.kwargs)
#
# File ~/.local/share/virtualenvs/BoneSegmentation-C6QGg7XR/lib/python3.9/site-packages/pyclesperanto_prototype/_tier9/_statistics_of_labelled_pixels.py:89, in statistics_of_labelled_pixels(intensity_image, label_image)
#      87 cumulative_stats_per_label_image = create([16, height, num_labels])
#      88 # init sum-fields with zero
# ---> 89 set(cumulative_stats_per_label_image, 0)
#      90 # before determining min/max, set initial values to very high and very low values
#      91 min_value = np.finfo(np.float32).min
#
# File ~/.local/share/virtualenvs/BoneSegmentation-C6QGg7XR/lib/python3.9/site-packages/pyclesperanto_prototype/_tier0/_plugin_function.py:71, in plugin_function.<locals>.worker_function(*args, **kwargs)
#      68         bound.arguments[key] = output_creator(*bound.args[:len(sig2.parameters)])
#      70 # call the decorated function
# ---> 71 return function(*bound.args, **bound.kwargs)
#
# File ~/.local/share/virtualenvs/BoneSegmentation-C6QGg7XR/lib/python3.9/site-packages/pyclesperanto_prototype/_tier1/_set.py:32, in set(source, scalar)
#       7 """Sets all pixel values x of a given image X to a constant value v.
#       8
#       9 <pre>f(x) = v</pre>
#    (...)
#      23 .. [1] https://clij.github.io/clij2-docs/reference_set
#      24 """
#      27 parameters = {
#      28     "dst":source,
#      29     "value":float(scalar)
#      30 }
# ---> 32 execute(__file__, '../clij-opencl-kernels/kernels/set_' + str(len(source.shape)) + 'd_x.cl', 'set_' + str(len(source.shape)) + 'd', source.shape, parameters);
#      33 return source
#
# File ~/.local/share/virtualenvs/BoneSegmentation-C6QGg7XR/lib/python3.9/site-packages/pyclesperanto_prototype/_tier0/_execute.py:3, in execute(anchor, opencl_kernel_filename, kernel_name, global_size, parameters, prog, constants, image_size_independent_kernel_compilation, device)
#       2 def execute(anchor, opencl_kernel_filename, kernel_name, global_size, parameters, prog = None, constants = None, image_size_independent_kernel_compilation : bool = None, device = None):
# ----> 3     return Backend.get_instance().get().execute(anchor, opencl_kernel_filename, kernel_name, global_size, parameters, prog, constants, image_size_independent_kernel_compilation, device)
#
# File ~/.local/share/virtualenvs/BoneSegmentation-C6QGg7XR/lib/python3.9/site-packages/pyclesperanto_prototype/_tier0/_opencl_backend.py:41, in OpenCLBackend.execute(self, anchor, opencl_kernel_filename, kernel_name, global_size, parameters, prog, constants, image_size_independent_kernel_compilation, device)
#      40 def execute(self, anchor, opencl_kernel_filename, kernel_name, global_size, parameters, prog = None, constants = None, image_size_independent_kernel_compilation : bool = None, device = None):
# ---> 41     return execute(anchor, opencl_kernel_filename, kernel_name, global_size, parameters, prog, constants, image_size_independent_kernel_compilation, device)
#
# File ~/.local/share/virtualenvs/BoneSegmentation-C6QGg7XR/lib/python3.9/site-packages/pyclesperanto_prototype/_tier0/_opencl_execute.py:322, in execute(anchor, opencl_kernel_filename, kernel_name, global_size, parameters, prog, constants, image_size_independent_kernel_compilation, device)
#     312     #prog = OCLProgram.from_source("\n".join(defines))
#     313
#     314     # Todo: the order of the arguments matters; fix that
#     315     # print("Compilation " + opencl_kernel_filename + " took " + str((time.time() - time_stamp) * 1000) + " ms")
#     316 else:
#     317     warnings.warn(
#     318         "The `prog` parameter of pyclesperanto_prototype.execute is deprecated since 0.11.0. It will be removed in 0.12.0.",
#     319         DeprecationWarning
#     320     )
# --> 322 prog.run_kernel(kernel_name, tuple(global_size[::-1]), None, *arguments)
#     324 return prog
#
# File ~/.local/share/virtualenvs/BoneSegmentation-C6QGg7XR/lib/python3.9/site-packages/pyclesperanto_prototype/_tier0/_program.py:34, in OCLProgram.run_kernel(self, name, global_size, local_size, *args, **kwargs)
#      31 if name not in self._kernel_dict:
#      32     self._kernel_dict[name] = getattr(self, name)
# ---> 34 self._kernel_dict[name](
#      35     self._dev.queue, global_size, local_size, *args, **kwargs
#      36 )
#      37 if OCLProgram._wait_for_kernel_finish:
#      38     self._dev.queue.finish()
#
# File ~/.local/share/virtualenvs/BoneSegmentation-C6QGg7XR/lib/python3.9/site-packages/pyopencl/__init__.py:901, in _add_functionality.<locals>.kernel_call(self, queue, global_size, local_size, *args, **kwargs)
#     895 def kernel_call(self, queue, global_size, local_size, *args, **kwargs):
#     896     # __call__ can't be overridden directly, so we need this
#     897     # trampoline hack.
#     898
#     899     # Note: This is only used for the generic __call__, before
#     900     # kernel_set_scalar_arg_dtypes is called.
# --> 901     return self._enqueue(self, queue, global_size, local_size, *args, **kwargs)
#
# File <pyopencl invoker for 'set_3d'>:8, in enqueue_knl_set_3d(self, queue, global_size, local_size, arg0, arg1, arg2, arg3, arg4, global_offset, g_times_l, allow_empty_ndrange, wait_for)
#
# MemoryError: clEnqueueNDRangeKernel failed: MEM_OBJECT_ALLOCATION_FAILURE

# %%
D = cle.euclidean_distance_from_label_centroid_map(smalls_filtered_out)
plt.figure(figsize=(18,12))
cle.imshow(D[40], labels=False)

# %%
max_peaks = cle.detect_maxima_box(D)
plt.figure(figsize=(18,12))
cle.imshow(max_peaks[40], labels=False)
# Out:
# size: 76

# %%
binarized = 3000 * (smalls_filtered_out > 0)

# %%
plt.figure(figsize=(18,12))
cle.imshow(binarized[40], labels=True)

# %%
image_with_segmentation = np.concatenate((viewer.arr, np.expand_dims(cle.pull(binarized), axis=0)), axis=0)
image_with_segmentation.shape
# Out:
# (4, 76, 2404, 3376)

# %%
viewer.save_as_tif_sequence(image_with_segmentation, "/home/dkermany/data/Bone_Project/tif_sequences/FV10__20190620_111343/NG2_segmentation/FV10__20190620_111343_NG2segmented")

# %%
np.unique(cle.pull(binarized))
# Out:
# array([   0, 3000], dtype=uint16)

# %%
image_with_segmentation.dtype
# Out:
# dtype('uint16')
